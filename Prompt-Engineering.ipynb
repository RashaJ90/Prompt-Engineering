# %%
pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 781.9 kB/s eta 0:00:00 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 3.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 1.4 MB/s eta 0:00:00
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# ...
#   WARNING: The script openai is installed in '/Users/rasha.j/Library/Python/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai
import os
import re
openai.api_key  = os.getenv('OPENAI_API_KEY') #

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %% [markdown]
# ## 1. Generation of GenAI Summer Camp Details:

# %%
summer_camp ="""
OVERVIEW
Welcome to GenAI Summer Camp: Where Creativity Meets Technology!
At GenAI Summer Camp, we believe in nurturing the next generation of innovators and tech enthusiasts. \
Our camp is a place where young minds can explore the exciting world of artificial intelligence, \
robotics, and computer science while fostering creativity, collaboration, and a sense of community. \
Join us for an unforgettable summer filled with cutting-edge learning experiences, \
exciting activities, and lifelong friendships!

CAMP OFFERINGS
- AI Exploration: Dive into the fascinating world of artificial intelligence. \
Learn about machine learning, neural networks, \
and natural language processing through hands-on projects and interactive workshops.

- Robotics Adventure: Build and program your own robots! \
From simple robots that follow lines to more complex creations, \
this program will ignite your passion for robotics.

- Game Development: Create your own video games from scratch. \
Learn coding, game design, and storytelling while bringing your ideas to life.

- Digital Art and Animation: Explore the intersection of art and technology. \
Develop your digital art skills and create animated masterpieces.

- STEM Challenges: Engage in daily STEM challenges that encourage problem-solving, \
critical thinking, and teamwork. Test your skills in engineering, physics, and mathematics.

- Virtual Reality (VR) Experience: Step into the world of VR. \
Design your virtual environments and experience immersive VR adventures.

OUR VALUES
Innovation: We foster a culture of innovation, encouraging campers to think creatively, \
explore new ideas, and embrace technology's potential.

Diversity and Inclusion: We welcome campers from all backgrounds \
and believe that diversity enriches our camp community. \
Everyone deserves a chance to learn and grow.

Collaboration: Campers work together on projects, \
learning the importance of teamwork, communication, and cooperation.

Safety: The safety and well-being of our campers are our top priorities. \
Our staff is trained in first aid, and our facilities are equipped to handle any situation.

Fun: Learning is fun! We create a vibrant and \
exciting atmosphere where campers can thrive and make lasting memories.

CAMP POLICIES
Code of Conduct: Respect, kindness, and inclusivity are non-negotiable. \
Campers must treat each other, the staff, and the camp facilities with respect.

Technology Use: While technology is at the heart of our camp, \
we encourage a healthy balance. Campers will have designated tech-free times and activities.

Safety Protocols: We have strict safety protocols in place, \
including adult supervision at all times, security measures, \
and emergency procedures.

Zero Tolerance for Bullying: Bullying will not be tolerated, \
and we have a zero-tolerance policy. \
Campers who engage in bullying will be sent home.

LOCATION
GenAI Summer Camp is located in the picturesque mountains of Silicon Valley, \
California. Our campus is nestled among the redwoods, \
providing a serene and inspiring environment for learning and exploration. \
Campers will have access to state-of-the-art facilities, \
including modern classrooms, robotics labs, and outdoor recreational areas.

DATES
Our summer camp sessions run for six weeks, \
starting on June 15th and ending on July 27th. \
Campers can choose to attend one or more sessions, \
tailoring their camp experience to their interests and availability.

PRICING
Full Session (6 weeks): $3,500
Half Session (3 weeks): $1,800
Single Week: $700
We offer scholarships and financial aid for families in need. \
Our goal is to make the camp accessible to everyone, 
regardless of their financial situation.

AGE RANGE
GenAI Summer Camp is open to campers aged 10 to 17.\
We offer age-appropriate programs and activities to ensure \
that campers receive a personalized learning experience tailored to their developmental stage.

ENDING
Join us at GenAI Summer Camp for a summer filled with learning, laughter, and lasting friendships. Discover the exciting world of technology and innovation while creating memories that will last a lifetime. Don't miss out on this opportunity to be part of the future of tech!"""

# %% [markdown]
# ## 2. Creating the Assistant with LLM:

# %%
router_prompt = f"""
You are an AssistantBot, an automated service to assist parents \ 
by answering their questions or \
register their children to GenAI Summer Camp \
You first greet the parent\
and then ask them if they would like to register their child \

determine their answer as yes or no only
"""
response = get_completion(router_prompt)
print(response)

context_router = [{'role':'system', 'content':router_prompt}]
messages =  context_router.copy()
messages.append(
{'role':'system', 'content':'create a json answer of the previous assitant'}   
)
router_response = get_completion_from_messages(messages, temperature=0)
print(router_response)
# Out:
# Hello! I am AssistantBot, an automated service here to assist you. How can I help you today? Would you like to register your child for GenAI Summer Camp? Please answer with a simple "yes" or "no".
# {
#   "message": "Hello! How can I assist you today? Would you like to register your child for GenAI Summer Camp?",
#   "suggestedUserResponses": [
#     "Yes, I would like to register my child.",
#     "No, I have some questions about the camp.",
#     "No, I am not interested in registering my child."
#   ]
# }

# %%
response= json.loads(router_response)
router_answer = f""""""
if re.findall(r'Yes', response["suggestedUserResponses"][0]):
    router_answer = f"""Yes"""
else:
    router_answer = f"""No"""

# %%
question_prompt = f"""
You are an AssistantBot, an automated service to assist parents \
by answering their questions regarding our GenAI Summer Camp specification \

write a very sound and clear answer to the parent \
when they ask about each of the specification \
descripted here: ```{summer_camp}```
"""
question_response = get_completion(question_prompt)
print(question_response)
context_question = [{'role':'system', 'content':question_prompt}]
messages =  context_question.copy()
messages.append(
{'role':'system', 'content':'create a json answer of the previous assitant'}   
)
question_response = get_completion_from_messages(messages, temperature=0)
print(question_response)
# Out:
# - Offerings: Our GenAI Summer Camp offers a variety of exciting programs for your child to choose from. They can explore the fascinating world of artificial intelligence through hands-on projects and interactive workshops in our AI Exploration program. They can also build and program their own robots in our Robotics Adventure program, starting from simple robots that follow lines to more complex creations. If your child is interested in video games, they can create their own from scratch in our Game Development program, where they will learn coding, game design, and storytelling. For those interested in art and technology, our Digital Art and Animation program allows campers to develop their digital art skills and create animated masterpieces. We also have STEM Challenges that encourage problem-solving, critical thinking, and teamwork in engineering, physics, and mathematics. Lastly, campers can step into the world of virtual reality in our Virtual Reality (VR) Experience program, wh
# ...

# %%
application_prompt = f"""
You are an AssistantBot, an automated service to assist parents \
by registerng their children to our GenAI Summer Camp specification \

ask the user respectfully one question at a time to provide you \ 
with the answers to the following questions:
 Preferred Camp Session \
How many children are intending to register \
child full name \
child's age \
Guardian full name \
contact email \
contact phone number \
Emergency Contact Information \
Any Special Requirements or Allergies for Your Child \
How did you hear about GenAI Summer Camp \
Do you have any specific questions or additional information you'd like to share \

then thank the parent and end the chat
"""
application_response = get_completion(application_prompt)
print(application_response)

context_application = [{'role':'system', 'content': application_prompt}]
messages =  context_application.copy()
messages.append(
{'role':'system', 'content':'create a json answer of the previous assitant questions and answers'}   
)
application_response = get_completion_from_messages(messages, temperature=0)
print(application_response)
# Out:
# Hello! Thank you for choosing GenAI Summer Camp. I would like to assist you in registering your child.
#
# 1. What is your preferred camp session?
# 2. How many children are you intending to register?
# 3. Could you please provide the full name of your child?
# 4. What is your child's age?
# 5. May I have the guardian's full name?
# 6. What is your contact email?
# 7. Could you please provide your contact phone number?
# 8. Do you have any emergency contact information?
# 9. Are there any special requirements or allergies for your child that we should be aware of?
# 10. How did you hear about GenAI Summer Camp?
# 11. Do you have any specific questions or additional information you'd like to share?
#
# Thank you for providing the information. We appreciate your interest in GenAI Summer Camp. If you have any further questions, feel free to ask.
# {
#   "Preferred Camp Session": "",
#   "Number of Children": "",
#   "Child Full Name": "",
#   "Child's Age": "",
# ...

# %% [markdown]
# ## 3. Open Questions:

# %% [markdown]
# 1. I would optimize by writing more specific and detailed instructions so it can understand and generate relevant responses. Define the model role more specifically as an assistant to the user with more data type and answers to learn from. Continuously test and iterate on more conversational prompts based on real-world interactions and documenting the responses to check for writing errors and optimizing instructions and avoid inapropriate or repeated errors.
# 2. By creating a test cases, I can evaluate the accuracy of the model performance
# 3. cancellation and refunds, user responses need to be wide ranged and multi, non-english speakers, consent signing, payments configurations, periodicaly discounts.
